# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion sw Hiperparámetros lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}

# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Sep 06 09:17:41 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671287 35.9 1473300    78.7 1473300  78.7
# Vcells 1242646  9.5 8388608    64.0 1978711  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
# Cambiar numero de experimento entre corridas
PARAM <- list()
PARAM$experimento <- 5959

# PARAM$semilla_primigenia <- 378089
# PARAM$semilla_primigenia <- 526121
# PARAM$semilla_primigenia <- 736063
PARAM$semilla_primigenia <- 802733

# %%
PARAM$kaggle$competencia <- "utn-2026-inicial"
PARAM$kaggle$cortes <- seq(9000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 100,
  learning_rate= 0.10,  # >=0
  feature_fraction= 1.0, # 0 < ff <= 1.0
  num_leaves= 32, # integer >= 2
  min_data_in_leaf= 20 # integer >= 0
)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83475
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion del Grid Search

# %%
# En el argumento x llegan los parmaetros de LightGBM
#  devuelve la AUC en cross validation del modelo entrenado

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)


  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " AUC ", AUC
  )

  return(AUC)
}

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
# Fase 2 con num_leaves=128, min_data_in_leaf=50.

tb_nueva <- CJ(
  num_leaves= c(30, 35, 40, 50),
  min_data_in_leaf= c(350, 400, 450, 500),
  learning_rate= c(0.01, 0.02, 0.03),
  feature_fraction= c(0.5, 0.7, 0.9),
  num_iterations= 9000
)

# %%
# veo que tiene la tabla antes de procesar
tb_nueva
# Out:
#     num_leaves min_data_in_leaf learning_rate feature_fraction num_iterations
# 1   30         350              0.01          0.5              9000
# 2   30         350              0.01          0.7              9000
# 3   30         350              0.01          0.9              9000
# 4   30         350              0.02          0.5              9000
# 5   30         350              0.02          0.7              9000
# 6   30         350              0.02          0.9              9000
# 7   30         350              0.03          0.5              9000
# 8   30         350              0.03          0.7              9000
# 9   30         350              0.03          0.9              9000
# 10  30         400              0.01          0.5              9000
# 11  30         400              0.01          0.7              9000
# 12  30         400              0.01          0.9              9000
# 13  30         400              0.02          0.5              9000
# 14  30         400              0.02          0.7              9000
# 15  30         400              0.02          0.9              9000
# 16  30         400              0.03          0.5              9000
# 17  30         400              0.03          0.7              9000
# 18  30         400              0.03          0.9              9000
# 19  30         450              0.01          0.5              9000
# 20  30         450              0.01          0.7              9000
# 21  30         450              0.01          0.9              9000
# 22  30         450              0.02          0.5              9000
# 23  30         450              0.02          0.7              9000
# 24  30         450              0.02          0.9              9000
# 25  30         450              0.03          0.5              9000
# 26  30         450              0.03          0.7              9000
# 27  30         450              0.03          0.9              9000
# 28  30         500              0.01          0.5              9000
# 29  30         500              0.01          0.7              9000
# 30  30         500              0.01          0.9              9000
# ⋮   ⋮          ⋮                ⋮             ⋮                ⋮
# 115 50         350              0.03          0.5              9000
# 116 50         350              0.03          0.7              9000
# 117 50         350              0.03          0.9              9000
# 118 50         400              0.01          0.5              9000
# 119 50         400              0.01          0.7              9000
# 120 50         400              0.01          0.9              9000
# 121 50         400              0.02          0.5              9000
# 122 50         400              0.02          0.7              9000
# 123 50         400              0.02          0.9              9000
# 124 50         400              0.03          0.5              9000
# 125 50         400              0.03          0.7              9000
# 126 50         400              0.03          0.9              9000
# 127 50         450              0.01          0.5              9000
# 128 50         450              0.01          0.7              9000
# 129 50         450              0.01          0.9              9000
# 130 50         450              0.02          0.5              9000
# 131 50         450              0.02          0.7              9000
# 132 50         450              0.02          0.9              9000
# 133 50         450              0.03          0.5              9000
# 134 50         450              0.03          0.7              9000
# 135 50         450              0.03          0.9              9000
# 136 50         500              0.01          0.5              9000
# 137 50         500              0.01          0.7              9000
# 138 50         500              0.01          0.9              9000
# 139 50         500              0.02          0.5              9000
# 140 50         500              0.02          0.7              9000
# 141 50         500              0.02          0.9              9000
# 142 50         500              0.03          0.5              9000
# 143 50         500              0.03          0.7              9000
# 144 50         500              0.03          0.9              9000

# %%
# registro a registro calculo la AUC
tb_nueva[, AUC:= Estimar_AUC_lightgbm( list(.SD)),
  by=1:nrow(tb_nueva) ]
# Out:
# Sun Sep 06 09:20:13 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926178725008911
#
# Sun Sep 06 09:20:27 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.92527217131792
#
# Sun Sep 06 09:20:42 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926729047131441
#
# Sun Sep 06 09:20:56 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.927633843376329
#
# Sun Sep 06 09:21:10 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.927156679310853
#
# Sun Sep 06 09:21:25 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926016654195561
#
# Sun Sep 06 09:21:39 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926377716847341
#
# Sun Sep 06 09:21:54 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925766446092269
#
# Sun Sep 06 09:22:08 PM 2026  list(num_leaves = 30, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.92390524128151
#
# Sun Sep 06 09:22:23 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924953188072217
#
# Sun Sep 06 09:22:37 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926747479179224
#
# Sun Sep 06 09:22:52 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925243594122285
#
# Sun Sep 06 09:23:06 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925471984351931
#
# Sun Sep 06 09:23:21 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925338651104232
#
# Sun Sep 06 09:23:35 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925057956970809
#
# Sun Sep 06 09:23:50 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926172025438209
#
# Sun Sep 06 09:24:04 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925754506186991
#
# Sun Sep 06 09:24:19 PM 2026  list(num_leaves = 30, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925351558665527
#
# Sun Sep 06 09:24:33 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925819960434232
#
# Sun Sep 06 09:24:48 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926017465008972
#
# Sun Sep 06 09:25:02 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.927027224340919
#
# Sun Sep 06 09:25:17 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926466491126201
#
# Sun Sep 06 09:25:31 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925594768426295
#
# Sun Sep 06 09:25:45 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926217249666822
#
# Sun Sep 06 09:26:00 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.92497033453047
#
# Sun Sep 06 09:26:14 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925567145959914
#
# Sun Sep 06 09:26:36 PM 2026  list(num_leaves = 30, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926054159640419
#
# Sun Sep 06 09:26:51 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924985394217573
#
# Sun Sep 06 09:27:05 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925432711077901
#
# Sun Sep 06 09:27:20 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924382477828339
#
# Sun Sep 06 09:27:34 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925996841779397
#
# Sun Sep 06 09:27:49 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926991387445152
#
# Sun Sep 06 09:28:04 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925984253536179
#
# Sun Sep 06 09:28:18 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.927043786618358
#
# Sun Sep 06 09:28:33 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925002510146443
#
# Sun Sep 06 09:28:47 PM 2026  list(num_leaves = 30, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926395393283859
#
# Sun Sep 06 09:29:02 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.927476887928457
#
# Sun Sep 06 09:29:17 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.92567187604741
#
# Sun Sep 06 09:29:31 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925343946409112
#
# Sun Sep 06 09:29:46 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925744187393218
#
# Sun Sep 06 09:30:01 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926530721043721
#
# Sun Sep 06 09:30:15 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925740397069147
#
# Sun Sep 06 09:30:30 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.92450038970978
#
# Sun Sep 06 09:30:45 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925535833820467
#
# Sun Sep 06 09:30:59 PM 2026  list(num_leaves = 35, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925164616456524
#
# Sun Sep 06 09:31:14 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925137227731948
#
# Sun Sep 06 09:31:29 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925622113582874
#
# Sun Sep 06 09:31:43 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.927028240452727
#
# Sun Sep 06 09:31:58 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925892555395019
#
# Sun Sep 06 09:32:13 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925332873653008
#
# Sun Sep 06 09:32:27 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925041847169996
#
# Sun Sep 06 09:32:42 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926736928090217
#
# Sun Sep 06 09:32:56 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926420128858978
#
# Sun Sep 06 09:33:11 PM 2026  list(num_leaves = 35, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.92585809785841
#
# Sun Sep 06 09:33:25 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926079470523916
#
# Sun Sep 06 09:33:40 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926273566215709
#
# Sun Sep 06 09:33:55 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925496149647689
#
# Sun Sep 06 09:34:09 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925906547114234
#
# Sun Sep 06 09:34:24 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926920063024803
#
# Sun Sep 06 09:34:38 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926001392399071
#
# Sun Sep 06 09:34:53 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.92570562441651
#
# Sun Sep 06 09:35:07 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.92664650778624
#
# Sun Sep 06 09:35:22 PM 2026  list(num_leaves = 35, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925025401172604
#
# Sun Sep 06 09:35:37 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926620211717105
#
# Sun Sep 06 09:35:51 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925459043828031
#
# Sun Sep 06 09:36:06 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.923281975881319
#
# Sun Sep 06 09:36:20 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926889411543106
#
# Sun Sep 06 09:36:35 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925507702453896
#
# Sun Sep 06 09:36:49 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925036180723788
#
# Sun Sep 06 09:37:04 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925470498197244
#
# Sun Sep 06 09:37:19 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926860349925942
#
# Sun Sep 06 09:37:33 PM 2026  list(num_leaves = 35, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925889210308712
#
# Sun Sep 06 09:37:48 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924384534582232
#
# Sun Sep 06 09:38:02 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926435545864549
#
# Sun Sep 06 09:38:17 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925068650263073
#
# Sun Sep 06 09:38:31 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925719689445076
#
# Sun Sep 06 09:38:46 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.92665337847895
#
# Sun Sep 06 09:39:00 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926502909589961
#
# Sun Sep 06 09:39:15 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926175484770636
#
# Sun Sep 06 09:39:29 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926445836164682
#
# Sun Sep 06 09:39:44 PM 2026  list(num_leaves = 40, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926063085294804
#
# Sun Sep 06 09:39:58 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.927059270656887
#
# Sun Sep 06 09:40:13 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.924919112809288
#
# Sun Sep 06 09:40:28 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925178250306118
#
# Sun Sep 06 09:40:42 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925210441913631
#
# Sun Sep 06 09:40:57 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925703531030865
#
# Sun Sep 06 09:41:11 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.92639919997978
#
# Sun Sep 06 09:41:26 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925412766542426
#
# Sun Sep 06 09:41:41 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925739448920344
#
# Sun Sep 06 09:41:55 PM 2026  list(num_leaves = 40, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.92489403231681
#
# Sun Sep 06 09:42:10 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924392254816229
#
# Sun Sep 06 09:42:25 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925443630138456
#
# Sun Sep 06 09:42:39 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924910443318799
#
# Sun Sep 06 09:42:54 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926311466478245
#
# Sun Sep 06 09:43:08 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.924889088233212
#
# Sun Sep 06 09:43:22 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926538126198942
#
# Sun Sep 06 09:43:37 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925497574232956
#
# Sun Sep 06 09:43:51 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925727932232887
#
# Sun Sep 06 09:44:06 PM 2026  list(num_leaves = 40, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.92506447019231
#
# Sun Sep 06 09:44:20 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924765309189203
#
# Sun Sep 06 09:44:35 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925886677951088
#
# Sun Sep 06 09:44:49 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925530630700195
#
# Sun Sep 06 09:45:04 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926320286330961
#
# Sun Sep 06 09:45:19 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925886253634697
#
# Sun Sep 06 09:45:33 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924166902616681
#
# Sun Sep 06 09:45:48 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924941104548636
#
# Sun Sep 06 09:46:02 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925899768109386
#
# Sun Sep 06 09:46:17 PM 2026  list(num_leaves = 40, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924992126342795
#
# Sun Sep 06 09:46:31 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924773407085853
#
# Sun Sep 06 09:46:46 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926318544403307
#
# Sun Sep 06 09:47:00 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925839860049574
#
# Sun Sep 06 09:47:15 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925821950414478
#
# Sun Sep 06 09:47:29 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.92667220918131
#
# Sun Sep 06 09:47:44 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926380429914319
#
# Sun Sep 06 09:47:58 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926496004117008
#
# Sun Sep 06 09:48:13 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925203950696722
#
# Sun Sep 06 09:48:27 PM 2026  list(num_leaves = 50, min_data_in_leaf = 350, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926506620778578
#
# Sun Sep 06 09:48:42 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925752912367154
#
# Sun Sep 06 09:48:56 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925655254803792
#
# Sun Sep 06 09:49:11 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926116033854444
#
# Sun Sep 06 09:49:25 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925908589264971
#
# Sun Sep 06 09:49:40 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926609036979897
#
# Sun Sep 06 09:49:54 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926722585635447
#
# Sun Sep 06 09:50:09 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924990372528446
#
# Sun Sep 06 09:50:23 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926574757401361
#
# Sun Sep 06 09:50:38 PM 2026  list(num_leaves = 50, min_data_in_leaf = 400, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924509766314381
#
# Sun Sep 06 09:50:52 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.926258294674756
#
# Sun Sep 06 09:51:07 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925442033281613
#
# Sun Sep 06 09:51:21 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926021312871648
#
# Sun Sep 06 09:51:36 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925640884235629
#
# Sun Sep 06 09:51:50 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.923783687950544
#
# Sun Sep 06 09:52:05 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925221932418101
#
# Sun Sep 06 09:52:19 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925495939884419
#
# Sun Sep 06 09:52:33 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.926201222088687
#
# Sun Sep 06 09:52:48 PM 2026  list(num_leaves = 50, min_data_in_leaf = 450, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.924981073553825
#
# Sun Sep 06 09:53:02 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.5, num_iterations = 9000) AUC 0.925905931825987
#
# Sun Sep 06 09:53:17 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.7, num_iterations = 9000) AUC 0.925509439529069
#
# Sun Sep 06 09:53:31 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.01, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925063760127263
#
# Sun Sep 06 09:53:46 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.5, num_iterations = 9000) AUC 0.92618752266427
#
# Sun Sep 06 09:54:00 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.7, num_iterations = 9000) AUC 0.924402446801648
#
# Sun Sep 06 09:54:15 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.02, feature_fraction = 0.9, num_iterations = 9000) AUC 0.926592143373031
#
# Sun Sep 06 09:54:29 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.5, num_iterations = 9000) AUC 0.924832473576645
#
# Sun Sep 06 09:54:43 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 9000) AUC 0.924026516945643
#
# Sun Sep 06 09:54:58 PM 2026  list(num_leaves = 50, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.9, num_iterations = 9000) AUC 0.925136788739078

# %%
# veo que tiene la tabla DESPUES de procesar
tb_nueva
# Out:
#     num_leaves min_data_in_leaf learning_rate feature_fraction num_iterations
# 1   30         350              0.01          0.5              9000
# 2   30         350              0.01          0.7              9000
# 3   30         350              0.01          0.9              9000
# 4   30         350              0.02          0.5              9000
# 5   30         350              0.02          0.7              9000
# 6   30         350              0.02          0.9              9000
# 7   30         350              0.03          0.5              9000
# 8   30         350              0.03          0.7              9000
# 9   30         350              0.03          0.9              9000
# 10  30         400              0.01          0.5              9000
# 11  30         400              0.01          0.7              9000
# 12  30         400              0.01          0.9              9000
# 13  30         400              0.02          0.5              9000
# 14  30         400              0.02          0.7              9000
# 15  30         400              0.02          0.9              9000
# 16  30         400              0.03          0.5              9000
# 17  30         400              0.03          0.7              9000
# 18  30         400              0.03          0.9              9000
# 19  30         450              0.01          0.5              9000
# 20  30         450              0.01          0.7              9000
# 21  30         450              0.01          0.9              9000
# 22  30         450              0.02          0.5              9000
# 23  30         450              0.02          0.7              9000
# 24  30         450              0.02          0.9              9000
# 25  30         450              0.03          0.5              9000
# 26  30         450              0.03          0.7              9000
# 27  30         450              0.03          0.9              9000
# 28  30         500              0.01          0.5              9000
# 29  30         500              0.01          0.7              9000
# 30  30         500              0.01          0.9              9000
# ⋮   ⋮          ⋮                ⋮             ⋮                ⋮
# 115 50         350              0.03          0.5              9000
# 116 50         350              0.03          0.7              9000
# 117 50         350              0.03          0.9              9000
# 118 50         400              0.01          0.5              9000
# 119 50         400              0.01          0.7              9000
# 120 50         400              0.01          0.9              9000
# 121 50         400              0.02          0.5              9000
# 122 50         400              0.02          0.7              9000
# 123 50         400              0.02          0.9              9000
# 124 50         400              0.03          0.5              9000
# 125 50         400              0.03          0.7              9000
# 126 50         400              0.03          0.9              9000
# 127 50         450              0.01          0.5              9000
# 128 50         450              0.01          0.7              9000
# 129 50         450              0.01          0.9              9000
# 130 50         450              0.02          0.5              9000
# 131 50         450              0.02          0.7              9000
# 132 50         450              0.02          0.9              9000
# 133 50         450              0.03          0.5              9000
# 134 50         450              0.03          0.7              9000
# 135 50         450              0.03          0.9              9000
# 136 50         500              0.01          0.5              9000
# 137 50         500              0.01          0.7              9000
# 138 50         500              0.01          0.9              9000
# 139 50         500              0.02          0.5              9000
# 140 50         500              0.02          0.7              9000
# 141 50         500              0.02          0.9              9000
# 142 50         500              0.03          0.5              9000
# 143 50         500              0.03          0.7              9000
# 144 50         500              0.03          0.9              9000
#     AUC
# 1   0.9261787
# 2   0.9252722
# 3   0.9267290
# 4   0.9276338
# 5   0.9271567
# 6   0.9260167
# 7   0.9263777
# 8   0.9257664
# 9   0.9239052
# 10  0.9249532
# 11  0.9267475
# 12  0.9252436
# 13  0.9254720
# 14  0.9253387
# 15  0.9250580
# 16  0.9261720
# 17  0.9257545
# 18  0.9253516
# 19  0.9258200
# 20  0.9260175
# 21  0.9270272
# 22  0.9264665
# 23  0.9255948
# 24  0.9262172
# 25  0.9249703
# 26  0.9255671
# 27  0.9260542
# 28  0.9249854
# 29  0.9254327
# 30  0.9243825
# ⋮   ⋮
# 115 0.9264960
# 116 0.9252040
# 117 0.9265066
# 118 0.9257529
# 119 0.9256553
# 120 0.9261160
# 121 0.9259086
# 122 0.9266090
# 123 0.9267226
# 124 0.9249904
# 125 0.9265748
# 126 0.9245098
# 127 0.9262583
# 128 0.9254420
# 129 0.9260213
# 130 0.9256409
# 131 0.9237837
# 132 0.9252219
# 133 0.9254959
# 134 0.9262012
# 135 0.9249811
# 136 0.9259059
# 137 0.9255094
# 138 0.9250638
# 139 0.9261875
# 140 0.9244024
# 141 0.9265921
# 142 0.9248325
# 143 0.9240265
# 144 0.9251368

# %%
# Cambiar nombre entre corridas
fwrite( tb_nueva,
  file= "tb_grid_serach_exp5959.txt",
  sep="\t",
  append= TRUE
)

# %%
setorder( tb_nueva, -AUC)
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC]
PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros
# Out:
# $num_leaves
# [1] 30
#
# $min_data_in_leaf
# [1] 350
#
# $learning_rate
# [1] 0.02
#
# $feature_fraction
# [1] 0.5
#
# $num_iterations
# [1] 9000

# %%
# Cambiar nombre entre corridas: PARAM_exp5940.yml
write_yaml( PARAM, file="PARAM_exp5959.yml")

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización de hiperparametros

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 802733
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 9000
#
# $learning_rate
# [1] 0.02
#
# $feature_fraction
# [1] 0.5
#
# $num_leaves
# [1] 30
#
# $min_data_in_leaf
# [1] 350

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# Cambiar nombre entre corridas
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo_exp5959.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# Cambiar nombre entre corridas
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo_exp5959.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# CAmbiar nombre entre corridas
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion_exp5959.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial

# %%
# Cambiar nombre entre corridas
write_yaml( PARAM, file="PARAM_exp5959.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Sep 06 10:20:05 PM 2026"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-04**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-04**  en caso de ser necesario.
