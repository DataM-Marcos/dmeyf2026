# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion sw Hiperparámetros lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}

# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Sep 01 03:10:54 AM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671287 35.9 1473300    78.7 1473300  78.7
# Vcells 1242646  9.5 8388608    64.0 1978711  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
# Cambiar numero de experimento entre corridas
PARAM <- list()
PARAM$experimento <- 5950

PARAM$semilla_primigenia <- 378089
# PARAM$semilla_primigenia <- 526121
# PARAM$semilla_primigenia <- 736063
# PARAM$semilla_primigenia <- 802733

# %%
PARAM$kaggle$competencia <- "utn-2026-inicial"
PARAM$kaggle$cortes <- seq(9000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 100,
  learning_rate= 0.10,  # >=0
  feature_fraction= 1.0, # 0 < ff <= 1.0
  num_leaves= 32, # integer >= 2
  min_data_in_leaf= 20 # integer >= 0
)

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83676
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion del Grid Search

# %%
# En el argumento x llegan los parmaetros de LightGBM
#  devuelve la AUC en cross validation del modelo entrenado

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)


  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " AUC ", AUC
  )

  return(AUC)
}

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
# Fase 2 con num_leaves=128, min_data_in_leaf=50.

tb_nueva <- CJ(
  num_leaves= c(8, 32, 64, 128),
  min_data_in_leaf= c(50, 200, 500, 1000, 2000),
  learning_rate= c(0.03, 0.05, 0.07),
  feature_fraction= c(0.7, 1.0),
  num_iterations= 3000
)

# %%
# veo que tiene la tabla antes de procesar
tb_nueva
# Out:
#     num_leaves min_data_in_leaf learning_rate feature_fraction num_iterations
# 1   8            50             0.03          0.7              3000
# 2   8            50             0.03          1.0              3000
# 3   8            50             0.05          0.7              3000
# 4   8            50             0.05          1.0              3000
# 5   8            50             0.07          0.7              3000
# 6   8            50             0.07          1.0              3000
# 7   8           200             0.03          0.7              3000
# 8   8           200             0.03          1.0              3000
# 9   8           200             0.05          0.7              3000
# 10  8           200             0.05          1.0              3000
# 11  8           200             0.07          0.7              3000
# 12  8           200             0.07          1.0              3000
# 13  8           500             0.03          0.7              3000
# 14  8           500             0.03          1.0              3000
# 15  8           500             0.05          0.7              3000
# 16  8           500             0.05          1.0              3000
# 17  8           500             0.07          0.7              3000
# 18  8           500             0.07          1.0              3000
# 19  8          1000             0.03          0.7              3000
# 20  8          1000             0.03          1.0              3000
# 21  8          1000             0.05          0.7              3000
# 22  8          1000             0.05          1.0              3000
# 23  8          1000             0.07          0.7              3000
# 24  8          1000             0.07          1.0              3000
# 25  8          2000             0.03          0.7              3000
# 26  8          2000             0.03          1.0              3000
# 27  8          2000             0.05          0.7              3000
# 28  8          2000             0.05          1.0              3000
# 29  8          2000             0.07          0.7              3000
# 30  8          2000             0.07          1.0              3000
# ⋮   ⋮          ⋮                ⋮             ⋮                ⋮
# 91  128          50             0.03          0.7              3000
# 92  128          50             0.03          1.0              3000
# 93  128          50             0.05          0.7              3000
# 94  128          50             0.05          1.0              3000
# 95  128          50             0.07          0.7              3000
# 96  128          50             0.07          1.0              3000
# 97  128         200             0.03          0.7              3000
# 98  128         200             0.03          1.0              3000
# 99  128         200             0.05          0.7              3000
# 100 128         200             0.05          1.0              3000
# 101 128         200             0.07          0.7              3000
# 102 128         200             0.07          1.0              3000
# 103 128         500             0.03          0.7              3000
# 104 128         500             0.03          1.0              3000
# 105 128         500             0.05          0.7              3000
# 106 128         500             0.05          1.0              3000
# 107 128         500             0.07          0.7              3000
# 108 128         500             0.07          1.0              3000
# 109 128        1000             0.03          0.7              3000
# 110 128        1000             0.03          1.0              3000
# 111 128        1000             0.05          0.7              3000
# 112 128        1000             0.05          1.0              3000
# 113 128        1000             0.07          0.7              3000
# 114 128        1000             0.07          1.0              3000
# 115 128        2000             0.03          0.7              3000
# 116 128        2000             0.03          1.0              3000
# 117 128        2000             0.05          0.7              3000
# 118 128        2000             0.05          1.0              3000
# 119 128        2000             0.07          0.7              3000
# 120 128        2000             0.07          1.0              3000

# %%
# registro a registro calculo la AUC
tb_nueva[, AUC:= Estimar_AUC_lightgbm( list(.SD)),
  by=1:nrow(tb_nueva) ]
# Out:
# Tue Sep 01 03:21:42 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926338836725643
#
# Tue Sep 01 03:21:57 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.92573785378341
#
# Tue Sep 01 03:22:12 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92672940674264
#
# Tue Sep 01 03:22:27 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926014450681924
#
# Tue Sep 01 03:22:43 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925093517303147
#
# Tue Sep 01 03:22:58 AM 2026  list(num_leaves = 8, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925329494371559
#
# Tue Sep 01 03:23:13 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925685322886722
#
# Tue Sep 01 03:23:28 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925458747817945
#
# Tue Sep 01 03:23:43 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.924961674168717
#
# Tue Sep 01 03:23:59 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925436991541809
#
# Tue Sep 01 03:24:14 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925363339812636
#
# Tue Sep 01 03:24:29 AM 2026  list(num_leaves = 8, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925976022759827
#
# Tue Sep 01 03:24:44 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926249524545805
#
# Tue Sep 01 03:24:59 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925874299991499
#
# Tue Sep 01 03:25:14 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925004597237658
#
# Tue Sep 01 03:25:29 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926169539837011
#
# Tue Sep 01 03:25:44 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925043560039082
#
# Tue Sep 01 03:25:59 AM 2026  list(num_leaves = 8, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.924922364003359
#
# Tue Sep 01 03:26:14 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926431330767033
#
# Tue Sep 01 03:26:28 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.926649935577456
#
# Tue Sep 01 03:26:43 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925269486736037
#
# Tue Sep 01 03:26:58 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925831706560886
#
# Tue Sep 01 03:27:12 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925020957674191
#
# Tue Sep 01 03:27:27 AM 2026  list(num_leaves = 8, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.92435513258386
#
# Tue Sep 01 03:27:42 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925930381684763
#
# Tue Sep 01 03:27:56 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925764053971355
#
# Tue Sep 01 03:28:11 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.924515313552499
#
# Tue Sep 01 03:28:26 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.92622893485146
#
# Tue Sep 01 03:28:44 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925926604682886
#
# Tue Sep 01 03:29:00 AM 2026  list(num_leaves = 8, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925438305944395
#
# Tue Sep 01 03:29:15 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926519595870602
#
# Tue Sep 01 03:29:30 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925990784810766
#
# Tue Sep 01 03:29:46 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926109008807928
#
# Tue Sep 01 03:30:01 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925112936352772
#
# Tue Sep 01 03:30:17 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925440436366664
#
# Tue Sep 01 03:30:32 AM 2026  list(num_leaves = 32, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.926113397015061
#
# Tue Sep 01 03:30:48 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925563078281939
#
# Tue Sep 01 03:31:03 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.926370922818014
#
# Tue Sep 01 03:31:19 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925287102269205
#
# Tue Sep 01 03:31:34 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925348852626724
#
# Tue Sep 01 03:31:49 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925665250083384
#
# Tue Sep 01 03:32:04 AM 2026  list(num_leaves = 32, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925838317757307
#
# Tue Sep 01 03:32:19 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925307086282922
#
# Tue Sep 01 03:32:34 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.924700694780755
#
# Tue Sep 01 03:32:53 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925652647333108
#
# Tue Sep 01 03:33:09 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925560114192428
#
# Tue Sep 01 03:33:24 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.927005054963653
#
# Tue Sep 01 03:33:40 AM 2026  list(num_leaves = 32, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925960764613322
#
# Tue Sep 01 03:33:55 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926101696523202
#
# Tue Sep 01 03:34:11 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925887809785112
#
# Tue Sep 01 03:34:26 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925724993961663
#
# Tue Sep 01 03:34:41 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.92588916481312
#
# Tue Sep 01 03:34:56 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926824353139311
#
# Tue Sep 01 03:35:12 AM 2026  list(num_leaves = 32, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925311566637183
#
# Tue Sep 01 03:35:27 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.924997623490861
#
# Tue Sep 01 03:35:42 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.926108838509943
#
# Tue Sep 01 03:35:58 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926029229181267
#
# Tue Sep 01 03:36:13 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.927123322102325
#
# Tue Sep 01 03:36:27 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926498013712152
#
# Tue Sep 01 03:36:43 AM 2026  list(num_leaves = 32, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925288636422025
#
# Tue Sep 01 03:36:59 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.927144259014432
#
# Tue Sep 01 03:37:14 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.92570803832792
#
# Tue Sep 01 03:37:30 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92524750123667
#
# Tue Sep 01 03:37:45 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926333886099789
#
# Tue Sep 01 03:38:01 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926619545226093
#
# Tue Sep 01 03:38:16 AM 2026  list(num_leaves = 64, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.92670282290457
#
# Tue Sep 01 03:38:32 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926144847919479
#
# Tue Sep 01 03:38:47 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925943527752516
#
# Tue Sep 01 03:39:03 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926187622140425
#
# Tue Sep 01 03:39:18 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926621734026888
#
# Tue Sep 01 03:39:33 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92513105572203
#
# Tue Sep 01 03:39:48 AM 2026  list(num_leaves = 64, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925736087961046
#
# Tue Sep 01 03:40:04 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92627783056237
#
# Tue Sep 01 03:40:19 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925979658111128
#
# Tue Sep 01 03:40:34 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.927467318990367
#
# Tue Sep 01 03:40:49 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925695815114518
#
# Tue Sep 01 03:41:04 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926472990417666
#
# Tue Sep 01 03:41:19 AM 2026  list(num_leaves = 64, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925127072688091
#
# Tue Sep 01 03:41:34 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926271544708024
#
# Tue Sep 01 03:41:49 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925643365748805
#
# Tue Sep 01 03:42:03 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.9257816531105
#
# Tue Sep 01 03:42:18 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.925964595559409
#
# Tue Sep 01 03:42:33 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925619411235655
#
# Tue Sep 01 03:42:49 AM 2026  list(num_leaves = 64, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925166867330859
#
# Tue Sep 01 03:43:05 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926578427512296
#
# Tue Sep 01 03:43:21 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925957935505996
#
# Tue Sep 01 03:43:36 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925902316879497
#
# Tue Sep 01 03:43:52 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.924972381582275
#
# Tue Sep 01 03:44:07 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92602749936772
#
# Tue Sep 01 03:44:22 AM 2026  list(num_leaves = 64, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.924398376577575
#
# Tue Sep 01 03:44:37 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925893121885758
#
# Tue Sep 01 03:44:53 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.926153466309008
#
# Tue Sep 01 03:45:08 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925043578853157
#
# Tue Sep 01 03:45:23 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.924905107499638
#
# Tue Sep 01 03:45:39 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925670334108326
#
# Tue Sep 01 03:45:54 AM 2026  list(num_leaves = 128, min_data_in_leaf = 50, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.926166005676034
#
# Tue Sep 01 03:46:10 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.927098119335765
#
# Tue Sep 01 03:46:25 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925049170822901
#
# Tue Sep 01 03:46:40 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925858781712916
#
# Tue Sep 01 03:46:56 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926149200558651
#
# Tue Sep 01 03:47:12 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.924551907640138
#
# Tue Sep 01 03:47:25 AM 2026  list(num_leaves = 128, min_data_in_leaf = 200, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.926518384777084
#
# Tue Sep 01 03:47:41 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.924867791536105
#
# Tue Sep 01 03:47:55 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925534543832897
#
# Tue Sep 01 03:48:10 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92539947269202
#
# Tue Sep 01 03:48:25 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.924725984049049
#
# Tue Sep 01 03:48:40 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926350124694587
#
# Tue Sep 01 03:48:54 AM 2026  list(num_leaves = 128, min_data_in_leaf = 500, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.926845535486455
#
# Tue Sep 01 03:49:09 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926461661926589
#
# Tue Sep 01 03:49:23 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.926306160232926
#
# Tue Sep 01 03:49:37 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925507037773303
#
# Tue Sep 01 03:49:52 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926607774765915
#
# Tue Sep 01 03:50:07 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925427346429079
#
# Tue Sep 01 03:50:21 AM 2026  list(num_leaves = 128, min_data_in_leaf = 1000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.926324531337295
#
# Tue Sep 01 03:50:37 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 0.7, num_iterations = 3000) AUC 0.926113896139991
#
# Tue Sep 01 03:50:51 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.03, feature_fraction = 1, num_iterations = 3000) AUC 0.925143958322986
#
# Tue Sep 01 03:51:07 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 0.7, num_iterations = 3000) AUC 0.92511061727332
#
# Tue Sep 01 03:51:20 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.05, feature_fraction = 1, num_iterations = 3000) AUC 0.926252060256891
#
# Tue Sep 01 03:51:35 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 0.7, num_iterations = 3000) AUC 0.925502508310048
#
# Tue Sep 01 03:51:49 AM 2026  list(num_leaves = 128, min_data_in_leaf = 2000, learning_rate = 0.07, feature_fraction = 1, num_iterations = 3000) AUC 0.925795795581748

# %%
# veo que tiene la tabla DESPUES de procesar
tb_nueva
# Out:
#     num_leaves min_data_in_leaf learning_rate feature_fraction num_iterations
# 1   8            50             0.03          0.7              3000
# 2   8            50             0.03          1.0              3000
# 3   8            50             0.05          0.7              3000
# 4   8            50             0.05          1.0              3000
# 5   8            50             0.07          0.7              3000
# 6   8            50             0.07          1.0              3000
# 7   8           200             0.03          0.7              3000
# 8   8           200             0.03          1.0              3000
# 9   8           200             0.05          0.7              3000
# 10  8           200             0.05          1.0              3000
# 11  8           200             0.07          0.7              3000
# 12  8           200             0.07          1.0              3000
# 13  8           500             0.03          0.7              3000
# 14  8           500             0.03          1.0              3000
# 15  8           500             0.05          0.7              3000
# 16  8           500             0.05          1.0              3000
# 17  8           500             0.07          0.7              3000
# 18  8           500             0.07          1.0              3000
# 19  8          1000             0.03          0.7              3000
# 20  8          1000             0.03          1.0              3000
# 21  8          1000             0.05          0.7              3000
# 22  8          1000             0.05          1.0              3000
# 23  8          1000             0.07          0.7              3000
# 24  8          1000             0.07          1.0              3000
# 25  8          2000             0.03          0.7              3000
# 26  8          2000             0.03          1.0              3000
# 27  8          2000             0.05          0.7              3000
# 28  8          2000             0.05          1.0              3000
# 29  8          2000             0.07          0.7              3000
# 30  8          2000             0.07          1.0              3000
# ⋮   ⋮          ⋮                ⋮             ⋮                ⋮
# 91  128          50             0.03          0.7              3000
# 92  128          50             0.03          1.0              3000
# 93  128          50             0.05          0.7              3000
# 94  128          50             0.05          1.0              3000
# 95  128          50             0.07          0.7              3000
# 96  128          50             0.07          1.0              3000
# 97  128         200             0.03          0.7              3000
# 98  128         200             0.03          1.0              3000
# 99  128         200             0.05          0.7              3000
# 100 128         200             0.05          1.0              3000
# 101 128         200             0.07          0.7              3000
# 102 128         200             0.07          1.0              3000
# 103 128         500             0.03          0.7              3000
# 104 128         500             0.03          1.0              3000
# 105 128         500             0.05          0.7              3000
# 106 128         500             0.05          1.0              3000
# 107 128         500             0.07          0.7              3000
# 108 128         500             0.07          1.0              3000
# 109 128        1000             0.03          0.7              3000
# 110 128        1000             0.03          1.0              3000
# 111 128        1000             0.05          0.7              3000
# 112 128        1000             0.05          1.0              3000
# 113 128        1000             0.07          0.7              3000
# 114 128        1000             0.07          1.0              3000
# 115 128        2000             0.03          0.7              3000
# 116 128        2000             0.03          1.0              3000
# 117 128        2000             0.05          0.7              3000
# 118 128        2000             0.05          1.0              3000
# 119 128        2000             0.07          0.7              3000
# 120 128        2000             0.07          1.0              3000
#     AUC
# 1   0.9263388
# 2   0.9257379
# 3   0.9267294
# 4   0.9260145
# 5   0.9250935
# 6   0.9253295
# 7   0.9256853
# 8   0.9254587
# 9   0.9249617
# 10  0.9254370
# 11  0.9253633
# 12  0.9259760
# 13  0.9262495
# 14  0.9258743
# 15  0.9250046
# 16  0.9261695
# 17  0.9250436
# 18  0.9249224
# 19  0.9264313
# 20  0.9266499
# 21  0.9252695
# 22  0.9258317
# 23  0.9250210
# 24  0.9243551
# 25  0.9259304
# 26  0.9257641
# 27  0.9245153
# 28  0.9262289
# 29  0.9259266
# 30  0.9254383
# ⋮   ⋮
# 91  0.9258931
# 92  0.9261535
# 93  0.9250436
# 94  0.9249051
# 95  0.9256703
# 96  0.9261660
# 97  0.9270981
# 98  0.9250492
# 99  0.9258588
# 100 0.9261492
# 101 0.9245519
# 102 0.9265184
# 103 0.9248678
# 104 0.9255345
# 105 0.9253995
# 106 0.9247260
# 107 0.9263501
# 108 0.9268455
# 109 0.9264617
# 110 0.9263062
# 111 0.9255070
# 112 0.9266078
# 113 0.9254273
# 114 0.9263245
# 115 0.9261139
# 116 0.9251440
# 117 0.9251106
# 118 0.9262521
# 119 0.9255025
# 120 0.9257958

# %%
# Cambiar nombre entre corridas
fwrite( tb_nueva,
  file= "tb_grid_serach_exp5950.txt",
  sep="\t",
  append= TRUE
)

# %%
setorder( tb_nueva, -AUC)
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC]
PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros
# Out:
# $num_leaves
# [1] 64
#
# $min_data_in_leaf
# [1] 500
#
# $learning_rate
# [1] 0.05
#
# $feature_fraction
# [1] 0.7
#
# $num_iterations
# [1] 3000

# %%
# Cambiar nombre entre corridas: PARAM_exp5940.yml
write_yaml( PARAM, file="PARAM_exp5950.yml")

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización de hiperparametros

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 378089
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 3000
#
# $learning_rate
# [1] 0.05
#
# $feature_fraction
# [1] 0.7
#
# $num_leaves
# [1] 64
#
# $min_data_in_leaf
# [1] 500

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# Cambiar nombre entre corridas
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo_exp5950.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# Cambiar nombre entre corridas
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo_exp5950.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# CAmbiar nombre entre corridas
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion_exp5950.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2) Successfully submitted to UTN 2026 Inicial

# %%
# Cambiar nombre entre corridas
write_yaml( PARAM, file="PARAM_exp5950.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Sep 01 04:04:56 AM 2026"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-04**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-04**  en caso de ser necesario.
